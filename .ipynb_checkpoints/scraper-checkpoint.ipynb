# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
def get_text(url):
    r = requests.get(url)
    return r.text
url = 'https://techcrunch.com/automotive/page/1/'
tag_page = get_text(url)

# %%
tag_soup = BeautifulSoup(tag_page, 'html.parser')
data = pd.DataFrame(columns=['title', 'url', 'date', 'content'])
title_list = []
url_list = []
for link_code in tag_soup.find_all('h2', "post-title"):
    title_list.append(link_code.get_text().replace('\xa0', ' '))
    url_list.append(link_code.a.get('href'))

# %%
data['url'] = url_list
data['title'] = title_list

# %%
for i in data.index:
    article_url = data['url'][i]
    article_page = get_text(article_url)
    article_soup = BeautifulSoup(article_page, 'html.parser')
    div = article_soup.find('div','article-entry text')
    content = div.get_text()
    data.loc[i, 'content'] = content[3:]
    data.loc[i, 'date'] = data.loc[i, 'url'][23:33]

# %%
data.to_csv('article.csv')

# %%
data
# Out:
#                                                 title  \
# 0   Baidu plans to mass produce Level 4 self-drivi...
# 1   New Tesla voluntary recall applies to 11,000 M...
# 2         CarGurus spikes 72% in auto marketplace IPO
# 3   Waymo releases its first self-driving ‘Safety ...
# 4   LG to open Europe’s largest EV battery factory...
# 5   California DMV changes rules to allow testing ...
# 6   Porsche launches on-demand subscription for it...
# 7   Velodyne quadruples LiDAR production to meet s...
# 8   Nvidia built a real Holodeck, aimed at creativ...
# 9   Nvidia’s new Pegasus AI computer is designed t...
# 10  Deutsche Post DHL to deploy self-driving deliv...
# 11  Waymo teams with MADD, the NSC and more on sel...
# 12  Cruise acquires Strobe to help dramatically re...
# 13  Elon pushes back Tesla Semi unveiling to focus...
# 14  Udacity spin-out Voyage is testing self-drivin...
# 15  Dyson seeks to beat rivals on range with its e...
# 16   Judge delays Waymo/Uber trial until December 4th
# 17  GM’s Cruise explains why self-driving tests in...
# 18  Tesla electric semi truck possibly spied in ne...
# 19  The due diligence report commissioned by Uber ...
#
#                                                   url        date  \
# 0   https://techcrunch.com/2017/10/13/baidu-plans-...  2017/10/13
# 1   https://techcrunch.com/2017/10/12/new-tesla-vo...  2017/10/12
# 2   https://techcrunch.com/2017/10/12/cargurus-spi...  2017/10/12
# 3   https://techcrunch.com/2017/10/12/waymo-self-d...  2017/10/12
# 4   https://techcrunch.com/2017/10/12/lg-to-open-e...  2017/10/12
# 5   https://techcrunch.com/2017/10/11/california-d...  2017/10/11
# 6   https://techcrunch.com/2017/10/10/porsche-laun...  2017/10/10
# 7   https://techcrunch.com/2017/10/10/velodyne-qua...  2017/10/10
# 8   https://techcrunch.com/2017/10/10/nvidia-built...  2017/10/10
# 9   https://techcrunch.com/2017/10/10/nvidias-new-...  2017/10/10
# 10  https://techcrunch.com/2017/10/10/deutsche-pos...  2017/10/10
# 11  https://techcrunch.com/2017/10/09/waymo-teams-...  2017/10/09
# 12  https://techcrunch.com/2017/10/09/cruise-acqui...  2017/10/09
# 13  https://techcrunch.com/2017/10/06/elon-pushes-...  2017/10/06
# 14  https://techcrunch.com/2017/10/04/udacity-spin...  2017/10/04
# 15  https://techcrunch.com/2017/10/04/dyson-seeks-...  2017/10/04
# 16  https://techcrunch.com/2017/10/03/judge-delays...  2017/10/03
# 17  https://techcrunch.com/2017/10/03/gms-cruise-e...  2017/10/03
# 18  https://techcrunch.com/2017/10/03/tesla-electr...  2017/10/03
# 19  https://techcrunch.com/2017/10/02/the-due-dili...  2017/10/02
#
#                                               content
# 0   Baidu, China’s internet technology giant, hope...
# 1   Tesla is taking a “proactive measure” out of a...
# 2   Used-car marketplace CarGurus spiked more than...
# 3   Waymo launched a campaign earlier this week al...
# 4   LG is opening Europe’s largest factory for bui...
# 5   The California Department of Motor Vehicles is...
# 6   Want to drive a Porsche, without actually owni...
# 7   Velodyne, largely considered the current leade...
# 8   Nvidia CEO Jensen Huang once told me that one ...
# 9   Nvidia revealed a new artificial intelligence ...
# 10  At Nvidia’s GTC Europe conference today, one o...
# 11  Waymo is working with a number of organization...
# 12  Cruise, the self-driving car startup GM acquir...
# 13  Back at the beginning of September, Elon Musk ...
# 14  Voyage, the self-driving technology company th...
# 15  Dyson is building an electric car, the company...
# 16  This morning, Judge William Alsup ruled that t...
# 17  GM is sharing more info about its testing proc...
# 18  Is this the new semi truck Tesla is set to unv...
# 19  A potentially pivotal document in the legal fi...
